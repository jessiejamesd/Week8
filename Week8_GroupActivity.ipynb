# %% [markdown]
# #**Week8 - Group Activity on Correlation and Regression**

# %% [markdown]
# ######***Importing necessary libraries***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##**1. Read the data into python**

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# ######***Reading dataset Week_7_Activity_data.csv in to Python Environment using read_csv(). The first 5 observations are displayed.***

# %%
df=pd.read_csv('/content/gdrive/MyDrive/ICTAK/Week_7_Activity_data.csv')
df.head()
# Out:
#           ph    Hardness  ...  Trihalomethanes  Turbidity
# 0   8.316766  214.373394  ...       100.341674   4.628771
# 1   9.092223  181.101509  ...        31.997993   4.075075
# 2   5.584087  188.313324  ...        54.917862   2.559708
# 3  10.223862  248.071735  ...        84.603556   2.672989
# 4   8.635849  203.361523  ...        62.798309   4.401425
#
# [5 rows x 9 columns]

# %% [markdown]
# ######***Finding the no: of Observations***

# %%
df.shape
# Out:
# (2011, 9)

# %% [markdown]
# ##**Insights:**
#
#
# > _**2011** Observations and **9** Features found!_

# %% [markdown]
# ##**2. Check for null values**

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ph, Hardness, Solids, Chloramines, Sulfate, Conductivity, Organic_carbon, Trihalomethanes, Turbidity]
# Index: []

# %% [markdown]
# ##**Insights:**
#
#
# > _No Null Values Found!_

# %% [markdown]
# ######***Plotting a Histogram for all the features in the dataset***

# %%
for i in df.columns:
  sns.displot(data=df, x = df[i], kde=True)

# %% [markdown]
# ##**Insights:**
# _As visible from the Histogram,_
# *   **Solids** and **Conductivity** have **Positive Skewness**
# *   **Sulphate** have **Negative Skewness**
# *   All others are **Symmetricaly Skewed**

# %% [markdown]
# ##**3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.**

# %% [markdown]
# ######***Finding Correlation using corr() and Plotting a heatmap***

# %%
corrmatrix=df.corr()
plt.subplots(figsize=(10,8))
colormap = sns.color_palette("BrBG")
sns.heatmap(corrmatrix, annot=True, linewidth=1, cmap=colormap)

# %% [markdown]
# ##**Insights:**
# > _As visible from the heatmap, the variables **Hardness, Sulphate, Organic Carbon** has **Neither High Positive Correlation nor High Negative Correlation** with any of the features in the dataset_

# %% [markdown]
# ##**4. Carry out correlation analysis on the dataset and find the correlation factor between**
# a. ph and Chloramines

# %%
df[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %% [markdown]
# ##**Insights:**
#
#
# > _**ph** and **Chloramines** have a **Low Negative Correlation** with value **-0.024768**_

# %% [markdown]
# ##**4. Carry out correlation analysis on the dataset and find the correlation factor between**
# b. ph and Conductivity

# %%
df[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %% [markdown]
# ##**Insights:**
#
#
# > _**ph** and **Conductivity** have a **Low Positive Correlation** with value **0.014128**_
